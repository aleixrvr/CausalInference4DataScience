# %%
from numpy.random import choice, normal, seed
import statsmodels.formula.api as smf
import random
import pandas as pd

seed(1234)

# %%
n = 100

z = normal(loc=0, scale=.5, size=n)
x = normal(loc=0, scale=.5, size=n)
y = 3*x + 3*z + normal(loc=0, scale=.5, size=n)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

# %%
smf.ols(formula='y ~ x', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     108.4
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           1.57e-17
# Time:                        12:36:00   Log-Likelihood:                -185.31
# No. Observations:                 100   AIC:                             374.6
# Df Residuals:                      98   BIC:                             379.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1272      0.156     -0.814      0.417      -0.437       0.183
# x              3.0379      0.292     10.410      0.000       2.459       3.617
# ==============================================================================
# Omnibus:                        0.587   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.746   Jarque-Bera (JB):                0.514
# Skew:                           0.173   Prob(JB):                        0.773
# Kurtosis:                       2.936   Cond. No.                         1.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
smf.ols(formula='y ~ x + z', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     776.3
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           2.07e-60
# Time:                        12:36:00   Log-Likelihood:                -80.863
# No. Observations:                 100   AIC:                             167.7
# Df Residuals:                      97   BIC:                             175.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0152      0.055     -0.274      0.785      -0.125       0.095
# x              3.0496      0.103     29.545      0.000       2.845       3.255
# z              2.9915      0.114     26.199      0.000       2.765       3.218
# ==============================================================================
# Omnibus:                        4.455   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.108   Jarque-Bera (JB):                4.336
# Skew:                           0.508   Prob(JB):                        0.114
# Kurtosis:                       2.915   Cond. No.                         2.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
n = 100

z = normal(loc=0, scale=.5, size=n)
x = z + normal(loc=0, scale=.01, size=n)
y = 3*x + normal(loc=0, scale=.5, size=n)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

# %%
smf.ols(formula='y ~ x', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     1240.
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           2.00e-57
# Time:                        12:36:00   Log-Likelihood:                -66.350
# No. Observations:                 100   AIC:                             136.7
# Df Residuals:                      98   BIC:                             141.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0554      0.048      1.165      0.247      -0.039       0.150
# x              2.9365      0.083     35.209      0.000       2.771       3.102
# ==============================================================================
# Omnibus:                        0.523   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.770   Jarque-Bera (JB):                0.663
# Skew:                           0.078   Prob(JB):                        0.718
# Kurtosis:                       2.633   Cond. No.                         1.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
smf.ols(formula='y ~ x + z', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     614.3
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           8.35e-56
# Time:                        12:36:00   Log-Likelihood:                -66.292
# No. Observations:                 100   AIC:                             138.6
# Df Residuals:                      97   BIC:                             146.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0557      0.048      1.165      0.247      -0.039       0.151
# x              1.2625      4.997      0.253      0.801      -8.656      11.181
# z              1.6728      4.993      0.335      0.738      -8.237      11.582
# ==============================================================================
# Omnibus:                        0.567   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.692
# Skew:                           0.066   Prob(JB):                        0.707
# Kurtosis:                       2.614   Cond. No.                         149.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
